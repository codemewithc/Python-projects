# %%
pip install --upgrade beautifulsoup4

# %%
# !pip install beautifulsoup4==4.10.0
# !pip install lxml
# !pip install html5lib==1.1
# !pip install pandas
# !pip install requests==2.26.0

# %%
import warnings
warnings.simplefilter("ignore")

from bs4 import BeautifulSoup
import requests

html="<!DOCTYPE html><html><head><title>Page Title</title></head><body><h3><b id='boldest'>Lebron James</b><p> Salary: $ 92,000,000 </p><h3><b> Stephen Curry </b></h3><p> Salary: $85,000, 000 </p><h3><b>  Kevin Durant </b></h3><p> Salary: $70,000, 000 </p></body></html>"

soup = BeautifulSoup(html, "html.parser")

print(soup.prettify())

tag_obj = soup.title

print("tag object:", tag_obj)
# Out:
# <!DOCTYPE html>
# <html>
#  <head>
#   <title>
#    Page Title
#   </title>
#  </head>
#  <body>
#   <h3>
#    <b id="boldest">
#     Lebron James
#    </b>
#    <p>
#     Salary: $ 92,000,000
#    </p>
#    <h3>
#     <b>
#      Stephen Curry
#     </b>
#    </h3>
#    <p>
#     Salary: $85,000, 000
#    </p>
#    <h3>
#     <b>
#      Kevin Durant
#     </b>
#    </h3>
#    <p>
#     Salary: $70,000, 000
#    </p>
#   </h3>
#  </body>
# </html>
# tag object: <title>Page Title</title>

# %%
print("tag object type:",type(tag_obj))
# Out:
# tag object type: <class 'bs4.element.Tag'>

# %%
tag_obj = soup.h3
tag_obj
# Out:
# <h3><b id="boldest">Lebron James</b><p> Salary: $ 92,000,000 </p><h3><b> Stephen Curry </b></h3><p> Salary: $85,000, 000 </p><h3><b>  Kevin Durant </b></h3><p> Salary: $70,000, 000 </p></h3>

# %%
tag_child = soup.b
tag_child
# Out:
# <b id="boldest">Lebron James</b>

# %%
tag_parent = tag_child.parent
tag_parent
# Out:
# <h3><b id="boldest">Lebron James</b><p> Salary: $ 92,000,000 </p><h3><b> Stephen Curry </b></h3><p> Salary: $85,000, 000 </p><h3><b>  Kevin Durant </b></h3><p> Salary: $70,000, 000 </p></h3>

# %%
tag_child.parent
# Out:
# <h3><b id="boldest">Lebron James</b><p> Salary: $ 92,000,000 </p><h3><b> Stephen Curry </b></h3><p> Salary: $85,000, 000 </p><h3><b>  Kevin Durant </b></h3><p> Salary: $70,000, 000 </p></h3>

# %%
sibling_1=tag_child.next_sibling
sibling_1
# Out:
# <p> Salary: $ 92,000,000 </p>

# %%
sibling_2=sibling_1.next_sibling
sibling_2
# Out:
# <h3><b> Stephen Curry </b></h3>

# %%
# Exercise: next_sibling
# Using the object sibling_2 and the property next_sibling to find the salary of Stephen Curry:

sibling_3 = sibling_2.next_sibling
sibling_3
# Out:
# <p> Salary: $85,000, 000 </p>

# %%
tag_string=tag_child.string
tag_string
# Out:
# 'Lebron James'

# %%
n_tag_child=tag_child.next_sibling
n_tag_child.string
# Out:
# ' Salary: $ 92,000,000 '

# %%
table = "<table><tr><td id='flight' >Flight No</td><td>Launch site</td><td>Payload mass</td></tr><tr><td>1</td><td><a href='https://en.wikipedia.org/wiki/Florida'>Florida</a></td><td>300 kg </td></tr><tr><td>2</td><td><a href='https://en.wikipedia.org/wiki/Texas'>Texas</a></td><td>94 kg</td></tr></table> "

table_bs = BeautifulSoup(table, "html.parser")

table_rows=table_bs.find_all('tr')
table_rows
# Out:
# [<tr><td id="flight">Flight No</td><td>Launch site</td><td>Payload mass</td></tr>,
#  <tr><td>1</td><td><a href="https://en.wikipedia.org/wiki/Florida">Florida</a></td><td>300 kg </td></tr>,
#  <tr><td>2</td><td><a href="https://en.wikipedia.org/wiki/Texas">Texas</a></td><td>94 kg</td></tr>]

# %%
first_row = table_rows[0]
first_row
# Out:
# <tr><td id="flight">Flight No</td><td>Launch site</td><td>Payload mass</td></tr>

# %%
print(type(first_row))
# Out:
# <class 'bs4.element.Tag'>

# %%
first_row.td
# Out:
# <td id="flight">Flight No</td>

# %%
for i,row in enumerate(table_rows):
    print("row",i,"is",row)
    cells = row.find_all('td')
    for j,cells in enumerate(cells):
        print("column",j,"is", cells)
# Out:
# row 0 is <tr><td id="flight">Flight No</td><td>Launch site</td><td>Payload mass</td></tr>
# column 0 is <td id="flight">Flight No</td>
# column 1 is <td>Launch site</td>
# column 2 is <td>Payload mass</td>
# row 1 is <tr><td>1</td><td><a href="https://en.wikipedia.org/wiki/Florida">Florida</a></td><td>300 kg </td></tr>
# column 0 is <td>1</td>
# column 1 is <td><a href="https://en.wikipedia.org/wiki/Florida">Florida</a></td>
# column 2 is <td>300 kg </td>
# row 2 is <tr><td>2</td><td><a href="https://en.wikipedia.org/wiki/Texas">Texas</a></td><td>94 kg</td></tr>
# column 0 is <td>2</td>
# column 1 is <td><a href="https://en.wikipedia.org/wiki/Texas">Texas</a></td>
# column 2 is <td>94 kg</td>

# %%
list_input=table_bs .find_all(name=["tr", "td"])
list_input
# Out:
# [<tr><td id="flight">Flight No</td><td>Launch site</td><td>Payload mass</td></tr>,
#  <td id="flight">Flight No</td>,
#  <td>Launch site</td>,
#  <td>Payload mass</td>,
#  <tr><td>1</td><td><a href="https://en.wikipedia.org/wiki/Florida">Florida</a></td><td>300 kg </td></tr>,
#  <td>1</td>,
#  <td><a href="https://en.wikipedia.org/wiki/Florida">Florida</a></td>,
#  <td>300 kg </td>,
#  <tr><td>2</td><td><a href="https://en.wikipedia.org/wiki/Texas">Texas</a></td><td>94 kg</td></tr>,
#  <td>2</td>,
#  <td><a href="https://en.wikipedia.org/wiki/Texas">Texas</a></td>,
#  <td>94 kg</td>]

# %%
table_bs.find_all('a', href=False)
# Out:
# []
